# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhailarifhussain/NED-PGD-Batch4-Python-/blob/main/final_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
file = pd.read_excel(r"path/name.xlsx")
Code = file.iloc[0,1]
Employee = file.iloc[0,6]
df = file[~file.iloc[:,0].isna()]
df1 = df.iloc[:, [0,5,9,14,16,21]]
df1.columns = df1.iloc[1,:]

df1 = df1[df1['Client ']!='Code:']
df1 = df1[df1['Client ']!="Client "]

df1 = df1.fillna(0)
df1.reset_index(drop=True, inplace=True)

#del df1['index']

column_to_check = df1.iloc[:, 0]


condition = ~column_to_check.astype(str).str.contains(r'Printed On', case=False, na=False)
condition_2 = ~column_to_check.astype(str).str.contains(r"Timesheet for the period", case=False, na=False)


df1 = df1[condition]
df1 = df1[condition_2]

df1 = df1[df1['Hours']!=float]
df1['Hours'].astype(float)


df1 = df1[df1['Client ']!="Total For Chargeable Time"]


ab = pd.DataFrame(columns=['Name', 'Date', 'Client_name', 'Client_code', 'Service', 'Job', 'Task', 'Analysis', 'Hours', 'Description'])


date = None
for i in range(len(df1)):
    x = df1.iloc[i,:]
    if (type(x.iloc[0]) == datetime):
        date = x.iloc[0]
        dt_object = datetime.strptime(str(date), '%Y-%m-%d %H:%M:%S')
        date = dt_object.strftime('%Y-%m-%d')
    elif x.iloc[-1]==0:
        ab.loc[i-1,"Client_name"] = x.iloc[0]
        ab.loc[i-1,"Description"] = x.iloc[2]
    else:
        ab.loc[i,"Name"] = Employee
        ab.loc[i, 'Date'] = date
        ab.loc[i, "Client_code"] = x.iloc[0]
        ab.loc[i,"Service"] = x.iloc[1]
        ab.loc[i, "Job"] = x.iloc[2]
        ab.loc[i, "Task"] = x.iloc[3]
        ab.loc[i, "Analysis"] = x.iloc[4]
        ab.loc[i, "Hours"] = x.iloc[5]




ab = ab[~ab['Client_name'].isna()]
ab = ab[~ab["Service"].isna()]

ab.reset_index(drop=True, inplace=True)
ab.index +=1

ab['Job/Tasks'] = ab['Job'].str.cat(ab['Task'], sep='/')
ab['Services/Analysis'] = ab['Service'].str.cat(ab['Analysis'], sep='/')
ab.drop(['Service', 'Task', 'Analysis', 'Job'], axis=1, inplace=True)


cols_order = ['Name', 'Date', 'Client_name', 'Client_code', 'Job/Tasks',
       'Services/Analysis', 'Description', 'Hours']

final_df = ab.reindex(columns=cols_order)
final_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f3c9445df6df> in <cell line: 1>()
# ----> 1 file = pd.read_excel(r"path/name.xlsx")
#       2 Code = file.iloc[0,1]
#       3 Employee = file.iloc[0,6]
#       4 df = file[~file.iloc[:,0].isna()]
#       5 df1 = df.iloc[:, [0,5,9,14,16,21]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/name.xlsx'

# %%
#ab['Hours'].sum()
# Out:
# 80.02

# %%
#final_df.to_excel(r"path/name.xlsx")

# %%
final_df
# Out:
#          Name        Date                        Client_name Client_code  \
# 1   Saqib Ali  2023-10-09                       Sabden Trust      SAB002
# 2   Saqib Ali  2023-10-09                       Sabden Trust      SAB002
# 3   Saqib Ali  2023-10-10                       Sabden Trust      SAB002
# 4   Saqib Ali  2023-10-10                       Sabden Trust      SAB002
# 5   Saqib Ali  2023-10-10                       Sabden Trust      SAB002
# ..        ...         ...                                ...         ...
# 63  Saqib Ali  2023-10-24      Dr Challoner's Grammar School      DRC001
# 64  Saqib Ali  2023-10-24      Dr Challoner's Grammar School      DRC001
# 65  Saqib Ali  2023-10-24      Dr Challoner's Grammar School      DRC001
# 66  Saqib Ali  2023-10-24         Khalsa Academies Trust Ltd      KHA001
# 67  Saqib Ali  2023-10-24  The Western Charitable Foundation      THE015
#
#                          Job/Tasks          Services/Analysis  \
# 1   Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 2   Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 3   Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 4   Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 5   Assurance Work/Chargeable Work  Assurance/Chargeable Time
# ..                             ...                        ...
# 63  Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 64  Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 65  Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 66  Assurance Work/Chargeable Work  Assurance/Chargeable Time
# 67  Assurance Work/Chargeable Work  Assurance/Chargeable Time
#
#                                           Description Hours
# 1   Materiality calculation, Updating interim Work...  0.83
# 2             Mapping and Sampling of income and OPEX  0.93
# 3   Updating debtors and creditors working papers ...  1.72
# 4   Working on debtors, sampling of trade detbors,...  1.07
# 5     Working on fixed assets, updating working paper   0.9
# ..                                                ...   ...
# 63            Working on TB mapping and OPEX Sampling  1.38
# 64          Working on TB mapping and Income Sampling   1.5
# 65               Mapping of fixed assets and sampling   0.5
# 66                       TB Mapping and OPEX sampling   0.7
# 67  Working on identifying accruals, prepayments a...  1.12
#
# [67 rows x 8 columns]
